# %% [markdown]
# # Sports Analytics API Tutorial
# https://api-sports.io/documentation/football/v3
# In this tutorial, we'll explore how to use a sports analytics API to fetch data about football teams and rankings. We'll be using the API-Football service from api-sports.io.

# %%
import pprint
import requests
import dotenv
import os

# Load the environment variables
dotenv.load_dotenv()
# API_SPORT
# You need your own api key to use this API. Register here if you want to try https://api-sports.io/
api_key = os.getenv('API_SPORT')
# Base URL
base_url = "https://v3.football.api-sports.io/teams"

# Query parameters
params = {
    'league': 39, # Premier League
    'season': 2021
}

# Headers
headers = {
    'x-rapidapi-key': api_key,
    'x-rapidapi-host': 'v3.football.api-sports.io'
}


# Make the GET request
response = requests.get(base_url, headers=headers, params=params)

# Print the JSON response
pprint.pprint(response.json())
# Out:
# {'errors': {'token': 'Error/Missing application key. Go to '
#                      'https://www.api-football.com/documentation-v3 to learn '
#                      'how to get your API application key.'},
#  'get': 'teams',
#  'paging': {'current': 1, 'total': 1},
#  'parameters': {'league': '39', 'season': '2021'},
#  'response': [],
#  'results': 0}

# %%
# We can see, we have a list of dictionaries, each containing information about a football team.
lst_teams = response.json()['response']
lst_teams[0:2] # First two teams
# Out:
# [{'team': {'id': 33,
#    'name': 'Manchester United',
#    'code': 'MUN',
#    'country': 'England',
#    'founded': 1878,
#    'national': False,
#    'logo': 'https://media.api-sports.io/football/teams/33.png'},
#   'venue': {'id': 556,
#    'name': 'Old Trafford',
#    'address': 'Sir Matt Busby Way',
#    'city': 'Manchester',
#    'capacity': 76212,
#    'surface': 'grass',
#    'image': 'https://media.api-sports.io/football/venues/556.png'}},
#  {'team': {'id': 34,
#    'name': 'Newcastle',
#    'code': 'NEW',
#    'country': 'England',
#    'founded': 1892,
#    'national': False,
#    'logo': 'https://media.api-sports.io/football/teams/34.png'},
#   'venue': {'id': 562,
#    'name': "St. James' Park",
#    'address': 'St. James&apos; Street',
#    'city': 'Newcastle upon Tyne',
#    'capacity': 52758,
#    'surface': 'grass',
#    'image': 'https://media.api-sports.io/football/venues/562.png'}}]

# %%
team1 = lst_teams[0]
print(team1.keys())
print(team1['team'])
print(team1['venue'])
# Out:
# dict_keys(['team', 'venue'])
# {'id': 33, 'name': 'Manchester United', 'code': 'MUN', 'country': 'England', 'founded': 1878, 'national': False, 'logo': 'https://media.api-sports.io/football/teams/33.png'}
# {'id': 556, 'name': 'Old Trafford', 'address': 'Sir Matt Busby Way', 'city': 'Manchester', 'capacity': 76212, 'surface': 'grass', 'image': 'https://media.api-sports.io/football/venues/556.png'}

# %% [markdown]
# ## An other example, in the API there is the endpoint standings that gives us the ranking of the teams in a league.

# %%
import requests

# Base URL
base_url = "https://v3.football.api-sports.io/standings"

# Query parameters
params = {
    'league': 39,
    'season': 2021
}

# Headers
headers = {
    'x-rapidapi-key': api_key,
    'x-rapidapi-host': 'v3.football.api-sports.io'
}

# Make the GET request
response = requests.get(base_url, headers=headers, params=params)

# Print the JSON response
# Print the JSON response
pprint.pprint(response.json())
# Out:
# {'errors': [],
#  'get': 'standings',
#  'paging': {'current': 1, 'total': 1},
#  'parameters': {'league': '39', 'season': '2021'},
#  'response': [{'league': {'country': 'England',
#                           'flag': 'https://media.api-sports.io/flags/gb.svg',
#                           'id': 39,
#                           'logo': 'https://media.api-sports.io/football/leagues/39.png',
#                           'name': 'Premier League',
#                           'season': 2021,
#                           'standings': [[{'all': {'draw': 6,
#                                                   'goals': {'against': 26,
#                                                             'for': 99},
#                                                   'lose': 3,
#                                                   'played': 38,
#                                                   'win': 29},
#                                           'away': {'draw': 4,
#                                                    'goals': {'against': 11,
#                                                              'for': 41},
#                                                    'lose': 1,
#                                                    'played': 19,
#                                                    'win': 14},
#                                           'description': 'Promotion - '
#                                                          'Champions League '
#                                                          '(Group Stage)',
#                                           'form': 'WDWWW',
#                                           'goalsDiff': 73,
#                                           'group': 'Premier League',
#                                           'home': {'draw': 2,
#                                                    'goals': {'against': 15,
#                                                              'for': 58},
#                                                    'lose': 2,
#                                                    'played': 19,
#                                                    'win': 15},
#                                           'points': 93,
#                                           'rank': 1,
#                                           'status': 'same',
#                                           'team': {'id': 50,
#                                                    'logo': 'https://media.api-sports.io/football/teams/50.png',
#                                                    'name': 'Manchester City'},
#                                           'update': '2022-05-22T00:00:00+00:00'},
#                                          {'all': {'draw': 8,
#                                                   'goals': {'against': 26,
#                                                             'for': 94},
#                                                   'lose': 2,
#                                                   'played': 38,
#                                                   'win': 28},
#                                           'away': {'draw': 4,
#                                                    'goals': {'against': 17,
#                                                              'for': 45},
#                                                    'lose': 2,
#                                                    'played': 19,
#                                                    'win': 13},
#                                           'description': 'Promotion - '
#                                                          'Champions League '
#                                                          '(Group Stage)',
#                                           'form': 'WWWDW',
#                                           'goalsDiff': 68,
#                                           'group': 'Premier League',
#                                           'home': {'draw': 4,
#                                                    'goals': {'against': 9,
#                                                              'for': 49},
#                                                    'lose': 0,
#                                                    'played': 19,
#                                                    'win': 15},
#                                           'points': 92,
#                                           'rank': 2,
#                                           'status': 'same',
#                                           'team': {'id': 40,
#                                                    'logo': 'https://media.api-sports.io/football/teams/40.png',
#                                                    'name': 'Liverpool'},
#                                           'update': '2022-05-22T00:00:00+00:00'},
#                                          {'all': {'draw': 11,
#                                                   'goals': {'against': 33,
#                                                             'for': 76},
#                                                   'lose': 6,
#                                                   'played': 38,
#                                                   'win': 21},
#                                           'away': {'draw': 4,
#                                                    'goals': {'against': 11,
#                                                              'for': 39},
#                                                    'lose': 3,
#                                                    'played': 19,
#                                                    'win': 12},
#                                           'description': 'Promotion - '
#                                                          'Champions League '
#                                                          '(Group Stage)',
#                                           'form': 'WDWDL',
#                                           'goalsDiff': 43,
#                                           'group': 'Premier League',
#                                           'home': {'draw': 7,
#                                                    'goals': {'against': 22,
#                                                              'for': 37},
#                                                    'lose': 3,
#                                                    'played': 19,
#                                                    'win': 9},
#                                           'points': 74,
#                                           'rank': 3,
#                                           'status': 'same',
#                                           'team': {'id': 49,
#                                                    'logo': 'https://media.api-sports.io/football/teams/49.png',
#                                                    'name': 'Chelsea'},
#                                           'update': '2022-05-22T00:00:00+00:00'},
#                                          {'all': {'draw': 5,
#                                                   'goals': {'against': 40,
#                                                             'for': 69},
#                                                   'lose': 11,
#                                                   'played': 38,
#                                                   'win': 22},
#                                           'away': {'draw': 4,
#                                                    'goals': {'against': 21,
#                                                              'for': 31},
#                                                    'lose': 6,
#                                                    'played': 19,
#                                                    'win': 9},
#                                           'description': 'Promotion - '
#                                                          'Champions League '
#                                                          '(Group Stage)',
#                                           'form': 'WWWDW',
#                                           'goalsDiff': 29,
#                                           'group': 'Premier League',
#                                           'home': {'draw': 1,
#                                                    'goals': {'against': 19,
#                                                              'for': 38},
#                                                    'lose': 5,
#                                                    'played': 19,
#                                                    'win': 13},
#                                           'points': 71,
#                                           'rank': 4,
#                                           'status': 'same',
#                                           'team': {'id': 47,
#                                                    'logo': 'https://media.api-sports.io/football/teams/47.png',
#                                                    'name': 'Tottenham'},
#                                           'update': '2022-05-22T00:00:00+00:00'},
#                                          {'all': {'draw': 3,
#                                                   'goals': {'against': 48,
#                                                             'for': 61},
#                                                   'lose': 13,
#                                                   'played': 38,
#                                                   'win': 22},
#                                           'away': {'draw': 1,
#                                                    'goals': {'against': 31,
#                                                              'for': 26},
#                                                    'lose': 9,
#                                                    'played': 19,
#                                                    'win': 9},
#                                           'description': 'Promotion - Europa '
#                                                          'League (Group Stage)',
#                                           'form': 'WLLWW',
#                                           'goalsDiff': 13,
#                                           'group': 'Premier League',
#                                           'home': {'draw': 2,
#                                                    'goals': {'against': 17,
#                                                              'for': 35},
#                                                    'lose': 4,
#                                                    'played': 19,
#                                                    'win': 13},
#                                           'points': 69,
#                                           'rank': 5,
#                                           'status': 'same',
#                                           'team': {'id': 42,
#                                                    'logo': 'https://media.api-sports.io/football/teams/42.png',
#                                                    'name': 'Arsenal'},
#                                           'update': '2022-05-22T00:00:00+00:00'},
#                                          {'all': {'draw': 10,
#                                                   'goals': {'against': 57,
#                                                             'for': 57},
#                                                   'lose': 12,
#                                                   'played': 38,
#                                                   'win': 16},
#                                           'away': {'draw': 5,
#                                                    'goals': {'against': 35,
#                                                              'for': 25},
#                                                    'lose': 8,
#                                                    'played': 19,
#                                                    'win': 6},
#                                           'description': 'Promotion - Europa '
#                                                          'League (Group Stage)',
#                                           'form': 'LLWDL',
#                                           'goalsDiff': 0,
#                                           'group': 'Premier League',
#                                           'home': {'draw': 5,
#                                                    'goals': {'against': 22,
#                                                              'for': 32},
#                                                    'lose': 4,
#                                                    'played': 19,
#                                                    'win': 10},
#                                           'points': 58,
#                                           'rank': 6,
#                                           'status': 'same',
#                                           'team': {'id': 33,
#                                                    'logo': 'https://media.api-sports.io/football/teams/33.png',
#                                                    'name': 'Manchester United'},
#                                           'update': '2022-05-22T00:00:00+00:00'},
#                                          {'all': {'draw': 8,
#                                                   'goals': {'against': 51,
#                                                             'for': 60},
#                                                   'lose': 14,
#                                                   'played': 38,
#                                                   'win': 16},
#                                           'away': {'draw': 3,
#                                                    'goals': {'against': 25,
#                                                              'for': 27},
#                                                    'lose': 9,
#                                                    'played': 19,
#                                                    'win': 7},
#                                           'description': 'Promotion - Europa '
#                                                          'Conference League '
#                                                          '(Qualification)',
#                                           'form': 'LDWLL',
#                                           'goalsDiff': 9,
#                                           'group': 'Premier League',
#                                           'home': {'draw': 5,
#                                                    'goals': {'against': 26,
#                                                              'for': 33},
#                                                    'lose': 5,
#                                                    'played': 19,
#                                                    'win': 9},
#                                           'points': 56,
#                                           'rank': 7,
#                                           'status': 'same',
#                                           'team': {'id': 48,
#                                                    'logo': 'https://media.api-sports.io/football/teams/48.png',
#                                                    'name': 'West Ham'},
#                                           'update': '2022-05-22T00:00:00+00:00'},
#                                          {'all': {'draw': 10,
#                                                   'goals': {'against': 59,
#                                                             'for': 62},
#                                                   'lose': 14,
#                                                   'played': 38,
#                                                   'win': 14},
#                                           'away': {'draw': 6,
#                                                    'goals': {'against': 36,
#                                                              'for': 28},
#                                                    'lose': 9,
#                                                    'played': 19,
#                                                    'win': 4},
#                                           'description': None,
#                                           'form': 'WDWWL',
#                                           'goalsDiff': 3,
#                                           'group': 'Premier League',
#                                           'home': {'draw': 4,
#                                                    'goals': {'against': 23,
#                                                              'for': 34},
#                                                    'lose': 5,
#                                                    'played': 19,
#                                                    'win': 10},
#                                           'points': 52,
#                                           'rank': 8,
#                                           'status': 'same',
#                                           'team': {'id': 46,
#                                                    'logo': 'https://media.api-sports.io/football/teams/46.png',
#                                                    'name': 'Leicester'},
#                                           'update': '2022-05-22T00:00:00+00:00'},
#                                          {'all': {'draw': 15,
#                                                   'goals': {'against': 44,
#                                                             'for': 42},
#                                                   'lose': 11,
#                                                   'played': 38,
#                                                   'win': 12},
#                                           'away': {'draw': 8,
#                                                    'goals': {'against': 21,
#                                                              'for': 23},
#                                                    'lose': 4,
#                                                    'played': 19,
#                                                    'win': 7},
#                                           'description': None,
#                                           'form': 'WDWWD',
#                                           'goalsDiff': -2,
#                                           'group': 'Premier League',
#                                           'home': {'draw': 7,
#                                                    'goals': {'against': 23,
#                                                              'for': 19},
#                                                    'lose': 7,
#                                                    'played': 19,
#                                                    'win': 5},
#                                           'points': 51,
#                                           'rank': 9,
#                                           'status': 'same',
#                                           'team': {'id': 51,
#                                                    'logo': 'https://media.api-sports.io/football/teams/51.png',
#                                                    'name': 'Brighton'},
#                                           'update': '2022-05-22T00:00:00+00:00'},
#                                          {'all': {'draw': 6,
#                                                   'goals': {'against': 43,
#                                                             'for': 38},
#                                                   'lose': 17,
#                                                   'played': 38,
#                                                   'win': 15},
#                                           'away': {'draw': 3,
#                                                    'goals': {'against': 18,
#                                                              'for': 18},
#                                                    'lose': 8,
#                                                    'played': 19,
#                                                    'win': 8},
#                                           'description': None,
#                                           'form': 'LDLDL',
#                                           'goalsDiff': -5,
#                                           'group': 'Premier League',
#                                           'home': {'draw': 3,
#                                                    'goals': {'against': 25,
#                                                              'for': 20},
#                                                    'lose': 9,
#                                                    'played': 19,
#                                                    'win': 7},
#                                           'points': 51,
#                                           'rank': 10,
#                                           'status': 'same',
#                                           'team': {'id': 39,
#                                                    'logo': 'https://media.api-sports.io/football/teams/39.png',
#                                                    'name': 'Wolves'},
#                                           'update': '2022-05-22T00:00:00+00:00'},
#                                          {'all': {'draw': 10,
#                                                   'goals': {'against': 62,
#                                                             'for': 44},
#                                                   'lose': 15,
#                                                   'played': 38,
#                                                   'win': 13},
#                                           'away': {'draw': 4,
#                                                    'goals': {'against': 35,
#                                                              'for': 18},
#                                                    'lose': 10,
#                                                    'played': 19,
#                                                    'win': 5},
#                                           'description': None,
#                                           'form': 'WWLLW',
#                                           'goalsDiff': -18,
#                                           'group': 'Premier League',
#                                           'home': {'draw': 6,
#                                                    'goals': {'against': 27,
#                                                              'for': 26},
#                                                    'lose': 5,
#                                                    'played': 19,
#                                                    'win': 8},
#                                           'points': 49,
#                                           'rank': 11,
#                                           'status': 'same',
#                                           'team': {'id': 34,
#                                                    'logo': 'https://media.api-sports.io/football/teams/34.png',
#                                                    'name': 'Newcastle'},
#                                           'update': '2022-05-22T00:00:00+00:00'},
#                                          {'all': {'draw': 15,
#                                                   'goals': {'against': 46,
#                                                             'for': 50},
#                                                   'lose': 12,
#                                                   'played': 38,
#                                                   'win': 11},
#                                           'away': {'draw': 7,
#                                                    'goals': {'against': 29,
#                                                              'for': 23},
#                                                    'lose': 8,
#                                                    'played': 19,
#                                                    'win': 4},
#                                           'description': None,
#                                           'form': 'WLDWW',
#                                           'goalsDiff': 4,
#                                           'group': 'Premier League',
#                                           'home': {'draw': 8,
#                                                    'goals': {'against': 17,
#                                                              'for': 27},
#                                                    'lose': 4,
#                                                    'played': 19,
#                                                    'win': 7},
#                                           'points': 48,
#                                           'rank': 12,
#                                           'status': 'same',
#                                           'team': {'id': 52,
#                                                    'logo': 'https://media.api-sports.io/football/teams/52.png',
#                                                    'name': 'Crystal Palace'},
#                                           'update': '2022-05-22T00:00:00+00:00'},
#                                          {'all': {'draw': 7,
#                                                   'goals': {'against': 56,
#                                                             'for': 48},
#                                                   'lose': 18,
#                                                   'played': 38,
#                                                   'win': 13},
#                                           'away': {'draw': 4,
#                                                    'goals': {'against': 35,
#                                                              'for': 26},
#                                                    'lose': 9,
#                                                    'played': 19,
#                                                    'win': 6},
#                                           'description': None,
#                                           'form': 'LWWLD',
#                                           'goalsDiff': -8,
#                                           'group': 'Premier League',
#                                           'home': {'draw': 3,
#                                                    'goals': {'against': 21,
#                                                              'for': 22},
#                                                    'lose': 9,
#                                                    'played': 19,
#                                                    'win': 7},
#                                           'points': 46,
#                                           'rank': 13,
#                                           'status': 'same',
#                                           'team': {'id': 55,
#                                                    'logo': 'https://media.api-sports.io/football/teams/55.png',
#                                                    'name': 'Brentford'},
#                                           'update': '2022-05-22T00:00:00+00:00'},
#                                          {'all': {'draw': 6,
#                                                   'goals': {'against': 54,
#                                                             'for': 52},
#                                                   'lose': 19,
#                                                   'played': 38,
#                                                   'win': 13},
#                                           'away': {'draw': 1,
#                                                    'goals': {'against': 25,
#                                                              'for': 23},
#                                                    'lose': 11,
#                                                    'played': 19,
#                                                    'win': 7},
#                                           'description': None,
#                                           'form': 'LDDLW',
#                                           'goalsDiff': -2,
#                                           'group': 'Premier League',
#                                           'home': {'draw': 5,
#                                                    'goals': {'against': 29,
#                                                              'for': 29},
#                                                    'lose': 8,
#                                                    'played': 19,
#                                                    'win': 6},
#                                           'points': 45,
#                                           'rank': 14,
#                                           'status': 'same',
#                                           'team': {'id': 66,
#                                                    'logo': 'https://media.api-sports.io/football/teams/66.png',
#                                                    'name': 'Aston Villa'},
#                                           'update': '2022-05-22T00:00:00+00:00'},
#                                          {'all': {'draw': 13,
#                                                   'goals': {'against': 67,
#                                                             'for': 43},
#                                                   'lose': 16,
#                                                   'played': 38,
#                                                   'win': 9},
#                                           'away': {'draw': 6,
#                                                    'goals': {'against': 43,
#                                                              'for': 20},
#                                                    'lose': 10,
#                                                    'played': 19,
#                                                    'win': 3},
#                                           'description': None,
#                                           'form': 'LLLLD',
#                                           'goalsDiff': -24,
#                                           'group': 'Premier League',
#                                           'home': {'draw': 7,
#                                                    'goals': {'against': 24,
#                                                              'for': 23},
#                                                    'lose': 6,
#                                                    'played': 19,
#                                                    'win': 6},
#                                           'points': 40,
#                                           'rank': 15,
#                                           'status': 'same',
#                                           'team': {'id': 41,
#                                                    'logo': 'https://media.api-sports.io/football/teams/41.png',
#                                                    'name': 'Southampton'},
#                                           'update': '2022-05-22T00:00:00+00:00'},
#                                          {'all': {'draw': 6,
#                                                   'goals': {'against': 66,
#                                                             'for': 43},
#                                                   'lose': 21,
#                                                   'played': 38,
#                                                   'win': 11},
#                                           'away': {'draw': 4,
#                                                    'goals': {'against': 41,
#                                                              'for': 16},
#                                                    'lose': 13,
#                                                    'played': 19,
#                                                    'win': 2},
#                                           'description': None,
#                                           'form': 'LWLDW',
#                                           'goalsDiff': -23,
#                                           'group': 'Premier League',
#                                           'home': {'draw': 2,
#                                                    'goals': {'against': 25,
#                                                              'for': 27},
#                                                    'lose': 8,
#                                                    'played': 19,
#                                                    'win': 9},
#                                           'points': 39,
#                                           'rank': 16,
#                                           'status': 'same',
#                                           'team': {'id': 45,
#                                                    'logo': 'https://media.api-sports.io/football/teams/45.png',
#                                                    'name': 'Everton'},
#                                           'update': '2022-05-22T00:00:00+00:00'},
#                                          {'all': {'draw': 11,
#                                                   'goals': {'against': 79,
#                                                             'for': 42},
#                                                   'lose': 18,
#                                                   'played': 38,
#                                                   'win': 9},
#                                           'away': {'draw': 5,
#                                                    'goals': {'against': 41,
#                                                              'for': 23},
#                                                    'lose': 9,
#                                                    'played': 19,
#                                                    'win': 5},
#                                           'description': None,
#                                           'form': 'WDLLL',
#                                           'goalsDiff': -37,
#                                           'group': 'Premier League',
#                                           'home': {'draw': 6,
#                                                    'goals': {'against': 38,
#                                                              'for': 19},
#                                                    'lose': 9,
#                                                    'played': 19,
#                                                    'win': 4},
#                                           'points': 38,
#                                           'rank': 17,
#                                           'status': 'same',
#                                           'team': {'id': 63,
#                                                    'logo': 'https://media.api-sports.io/football/teams/63.png',
#                                                    'name': 'Leeds'},
#                                           'update': '2022-05-22T00:00:00+00:00'},
#                                          {'all': {'draw': 14,
#                                                   'goals': {'against': 53,
#                                                             'for': 34},
#                                                   'lose': 17,
#                                                   'played': 38,
#                                                   'win': 7},
#                                           'away': {'draw': 8,
#                                                    'goals': {'against': 28,
#                                                              'for': 16},
#                                                    'lose': 9,
#                                                    'played': 19,
#                                                    'win': 2},
#                                           'description': 'Relegation - '
#                                                          'Championship',
#                                           'form': 'LDLLW',
#                                           'goalsDiff': -19,
#                                           'group': 'Premier League',
#                                           'home': {'draw': 6,
#                                                    'goals': {'against': 25,
#                                                              'for': 18},
#                                                    'lose': 8,
#                                                    'played': 19,
#                                                    'win': 5},
#                                           'points': 35,
#                                           'rank': 18,
#                                           'status': 'same',
#                                           'team': {'id': 44,
#                                                    'logo': 'https://media.api-sports.io/football/teams/44.png',
#                                                    'name': 'Burnley'},
#                                           'update': '2022-05-22T00:00:00+00:00'},
#                                          {'all': {'draw': 5,
#                                                   'goals': {'against': 77,
#                                                             'for': 34},
#                                                   'lose': 27,
#                                                   'played': 38,
#                                                   'win': 6},
#                                           'away': {'draw': 3,
#                                                    'goals': {'against': 31,
#                                                              'for': 17},
#                                                    'lose': 12,
#                                                    'played': 19,
#                                                    'win': 4},
#                                           'description': 'Relegation - '
#                                                          'Championship',
#                                           'form': 'LLDLL',
#                                           'goalsDiff': -43,
#                                           'group': 'Premier League',
#                                           'home': {'draw': 2,
#                                                    'goals': {'against': 46,
#                                                              'for': 17},
#                                                    'lose': 15,
#                                                    'played': 19,
#                                                    'win': 2},
#                                           'points': 23,
#                                           'rank': 19,
#                                           'status': 'same',
#                                           'team': {'id': 38,
#                                                    'logo': 'https://media.api-sports.io/football/teams/38.png',
#                                                    'name': 'Watford'},
#                                           'update': '2022-05-22T00:00:00+00:00'},
#                                          {'all': {'draw': 7,
#                                                   'goals': {'against': 84,
#                                                             'for': 23},
#                                                   'lose': 26,
#                                                   'played': 38,
#                                                   'win': 5},
#                                           'away': {'draw': 4,
#                                                    'goals': {'against': 41,
#                                                              'for': 11},
#                                                    'lose': 13,
#                                                    'played': 19,
#                                                    'win': 2},
#                                           'description': 'Relegation - '
#                                                          'Championship',
#                                           'form': 'LDLLL',
#                                           'goalsDiff': -61,
#                                           'group': 'Premier League',
#                                           'home': {'draw': 3,
#                                                    'goals': {'against': 43,
#                                                              'for': 12},
#                                                    'lose': 13,
#                                                    'played': 19,
#                                                    'win': 3},
#                                           'points': 22,
#                                           'rank': 20,
#                                           'status': 'same',
#                                           'team': {'id': 71,
#                                                    'logo': 'https://media.api-sports.io/football/teams/71.png',
#                                                    'name': 'Norwich'},
#                                           'update': '2022-05-22T00:00:00+00:00'}]]}}],
#  'results': 1}

# %%
ranking_by_team = response.json()['response'][0]['league']['standings'][0]
first = ranking_by_team[0]
pprint.pprint(first)
# Out:
# {'all': {'draw': 11,
#          'goals': {'against': 23, 'for': 64},
#          'lose': 3,
#          'played': 38,
#          'win': 24},
#  'away': {'draw': 4,
#           'goals': {'against': 12, 'for': 36},
#           'lose': 1,
#           'played': 19,
#           'win': 14},
#  'description': 'Promotion - Champions League (Group Stage)',
#  'form': 'WDWWW',
#  'goalsDiff': 41,
#  'group': 'Ligue 1',
#  'home': {'draw': 7,
#           'goals': {'against': 11, 'for': 28},
#           'lose': 2,
#           'played': 19,
#           'win': 10},
#  'points': 83,
#  'rank': 1,
#  'status': 'same',
#  'team': {'id': 79,
#           'logo': 'https://media.api-sports.io/football/teams/79.png',
#           'name': 'Lille'},
#  'update': '2021-05-26T00:00:00+00:00'}

# %%
last = ranking_by_team[-1]
pprint.pprint(last)
# Out:
# {'all': {'draw': 9,
#          'goals': {'against': 73, 'for': 25},
#          'lose': 25,
#          'played': 38,
#          'win': 4},
#  'away': {'draw': 3,
#           'goals': {'against': 42, 'for': 17},
#           'lose': 13,
#           'played': 19,
#           'win': 3},
#  'description': 'Relegation - Ligue 2',
#  'form': 'WLLLL',
#  'goalsDiff': -48,
#  'group': 'Ligue 1',
#  'home': {'draw': 6,
#           'goals': {'against': 31, 'for': 8},
#           'lose': 12,
#           'played': 19,
#           'win': 1},
#  'points': 21,
#  'rank': 20,
#  'status': 'same',
#  'team': {'id': 89,
#           'logo': 'https://media.api-sports.io/football/teams/89.png',
#           'name': 'Dijon'},
#  'update': '2021-05-26T00:00:00+00:00'}

# %%
import requests

url = base_url = "https://v3.football.api-sports.io/leagues"
headers = {
    "x-rapidapi-key": api_key,
    "x-rapidapi-host": "v3.football.api-sports.io"
}

response = requests.get(url, headers=headers)
data = response.json()

pprint.pprint(data['response'][:3])
# Out:
# [{'country': {'code': None, 'flag': None, 'name': 'World'},
#   'league': {'id': 4,
#              'logo': 'https://media.api-sports.io/football/leagues/4.png',
#              'name': 'Euro Championship',
#              'type': 'Cup'},
#   'seasons': [{'coverage': {'fixtures': {'events': True,
#                                          'lineups': True,
#                                          'statistics_fixtures': False,
#                                          'statistics_players': False},
#                             'injuries': False,
#                             'odds': False,
#                             'players': True,
#                             'predictions': True,
#                             'standings': False,
#                             'top_assists': True,
#                             'top_cards': True,
#                             'top_scorers': True},
#                'current': False,
#                'end': '2008-06-29',
#                'start': '2008-06-07',
#                'year': 2008},
#               {'coverage': {'fixtures': {'events': True,
#                                          'lineups': True,
#                                          'statistics_fixtures': False,
#                                          'statistics_players': False},
#                             'injuries': False,
#                             'odds': False,
#                             'players': True,
#                             'predictions': True,
#                             'standings': False,
#                             'top_assists': True,
#                             'top_cards': True,
#                             'top_scorers': True},
#                'current': False,
#                'end': '2012-07-01',
#                'start': '2012-06-08',
#                'year': 2012},
#               {'coverage': {'fixtures': {'events': True,
#                                          'lineups': True,
#                                          'statistics_fixtures': True,
#                                          'statistics_players': True},
#                             'injuries': False,
#                             'odds': False,
#                             'players': True,
#                             'predictions': True,
#                             'standings': True,
#                             'top_assists': True,
#                             'top_cards': True,
#                             'top_scorers': True},
#                'current': False,
#                'end': '2016-07-10',
#                'start': '2016-06-10',
#                'year': 2016},
#               {'coverage': {'fixtures': {'events': True,
#                                          'lineups': True,
#                                          'statistics_fixtures': True,
#                                          'statistics_players': True},
#                             'injuries': False,
#                             'odds': False,
#                             'players': True,
#                             'predictions': True,
#                             'standings': True,
#                             'top_assists': True,
#                             'top_cards': True,
#                             'top_scorers': True},
#                'current': False,
#                'end': '2021-07-11',
#                'start': '2019-03-21',
#                'year': 2020},
#               {'coverage': {'fixtures': {'events': True,
#                                          'lineups': True,
#                                          'statistics_fixtures': True,
#                                          'statistics_players': True},
#                             'injuries': False,
#                             'odds': False,
#                             'players': True,
#                             'predictions': True,
#                             'standings': True,
#                             'top_assists': True,
#                             'top_cards': True,
#                             'top_scorers': True},
#                'current': True,
#                'end': '2024-07-14',
#                'start': '2024-06-14',
#                'year': 2024}]},
#  {'country': {'code': None, 'flag': None, 'name': 'World'},
#   'league': {'id': 21,
#              'logo': 'https://media.api-sports.io/football/leagues/21.png',
#              'name': 'Confederations Cup',
#              'type': 'Cup'},
#   'seasons': [{'coverage': {'fixtures': {'events': True,
#                                          'lineups': True,
#                                          'statistics_fixtures': False,
#                                          'statistics_players': False},
#                             'injuries': False,
#                             'odds': False,
#                             'players': True,
#                             'predictions': True,
#                             'standings': False,
#                             'top_assists': True,
#                             'top_cards': True,
#                             'top_scorers': True},
#                'current': False,
#                'end': '2009-06-28',
#                'start': '2009-06-14',
#                'year': 2009},
#               {'coverage': {'fixtures': {'events': True,
#                                          'lineups': True,
#                                          'statistics_fixtures': False,
#                                          'statistics_players': False},
#                             'injuries': False,
#                             'odds': False,
#                             'players': True,
#                             'predictions': True,
#                             'standings': False,
#                             'top_assists': True,
#                             'top_cards': True,
#                             'top_scorers': True},
#                'current': False,
#                'end': '2013-06-30',
#                'start': '2013-06-15',
#                'year': 2013},
#               {'coverage': {'fixtures': {'events': True,
#                                          'lineups': True,
#                                          'statistics_fixtures': True,
#                                          'statistics_players': False},
#                             'injuries': False,
#                             'odds': False,
#                             'players': True,
#                             'predictions': True,
#                             'standings': False,
#                             'top_assists': True,
#                             'top_cards': True,
#                             'top_scorers': True},
#                'current': True,
#                'end': '2017-07-02',
#                'start': '2017-06-17',
#                'year': 2017}]},
#  {'country': {'code': 'FR',
#               'flag': 'https://media.api-sports.io/flags/fr.svg',
#               'name': 'France'},
#   'league': {'id': 61,
#              'logo': 'https://media.api-sports.io/football/leagues/61.png',
#              'name': 'Ligue 1',
#              'type': 'League'},
#   'seasons': [{'coverage': {'fixtures': {'events': True,
#                                          'lineups': True,
#                                          'statistics_fixtures': False,
#                                          'statistics_players': False},
#                             'injuries': False,
#                             'odds': False,
#                             'players': True,
#                             'predictions': True,
#                             'standings': True,
#                             'top_assists': True,
#                             'top_cards': True,
#                             'top_scorers': True},
#                'current': False,
#                'end': '2011-05-29',
#                'start': '2010-08-07',
#                'year': 2010},
#               {'coverage': {'fixtures': {'events': True,
#                                          'lineups': True,
#                                          'statistics_fixtures': False,
#                                          'statistics_players': False},
#                             'injuries': False,
#                             'odds': False,
#                             'players': True,
#                             'predictions': True,
#                             'standings': True,
#                             'top_assists': True,
#                             'top_cards': True,
#                             'top_scorers': True},
#                'current': False,
#                'end': '2012-05-20',
#                'start': '2011-08-06',
#                'year': 2011},
#               {'coverage': {'fixtures': {'events': True,
#                                          'lineups': True,
#                                          'statistics_fixtures': False,
#                                          'statistics_players': False},
#                             'injuries': False,
#                             'odds': False,
#                             'players': True,
#                             'predictions': True,
#                             'standings': True,
#                             'top_assists': True,
#                             'top_cards': True,
#                             'top_scorers': True},
#                'current': False,
#                'end': '2013-05-26',
#                'start': '2012-08-10',
#                'year': 2012},
#               {'coverage': {'fixtures': {'events': True,
#                                          'lineups': True,
#                                          'statistics_fixtures': False,
#                                          'statistics_players': False},
#                             'injuries': False,
#                             'odds': False,
#                             'players': True,
#                             'predictions': True,
#                             'standings': True,
#                             'top_assists': True,
#                             'top_cards': True,
#                             'top_scorers': True},
#                'current': False,
#                'end': '2014-05-17',
#                'start': '2013-08-09',
#                'year': 2013},
#               {'coverage': {'fixtures': {'events': True,
#                                          'lineups': True,
#                                          'statistics_fixtures': False,
#                                          'statistics_players': False},
#                             'injuries': False,
#                             'odds': False,
#                             'players': True,
#                             'predictions': True,
#                             'standings': True,
#                             'top_assists': True,
#                             'top_cards': True,
#                             'top_scorers': True},
#                'current': False,
#                'end': '2015-05-23',
#                'start': '2014-08-08',
#                'year': 2014},
#               {'coverage': {'fixtures': {'events': True,
#                                          'lineups': True,
#                                          'statistics_fixtures': True,
#                                          'statistics_players': True},
#                             'injuries': False,
#                             'odds': False,
#                             'players': True,
#                             'predictions': True,
#                             'standings': True,
#                             'top_assists': True,
#                             'top_cards': True,
#                             'top_scorers': True},
#                'current': False,
#                'end': '2016-05-14',
#                'start': '2015-08-07',
#                'year': 2015},
#               {'coverage': {'fixtures': {'events': True,
#                                          'lineups': True,
#                                          'statistics_fixtures': True,
#                                          'statistics_players': True},
#                             'injuries': False,
#                             'odds': False,
#                             'players': True,
#                             'predictions': True,
#                             'standings': True,
#                             'top_assists': True,
#                             'top_cards': True,
#                             'top_scorers': True},
#                'current': False,
#                'end': '2017-05-20',
#                'start': '2016-08-12',
#                'year': 2016},
#               {'coverage': {'fixtures': {'events': True,
#                                          'lineups': True,
#                                          'statistics_fixtures': True,
#                                          'statistics_players': True},
#                             'injuries': False,
#                             'odds': False,
#                             'players': True,
#                             'predictions': True,
#                             'standings': True,
#                             'top_assists': True,
#                             'top_cards': True,
#                             'top_scorers': True},
#                'current': False,
#                'end': '2018-05-19',
#                'start': '2017-08-04',
#                'year': 2017},
#               {'coverage': {'fixtures': {'events': True,
#                                          'lineups': True,
#                                          'statistics_fixtures': True,
#                                          'statistics_players': True},
#                             'injuries': False,
#                             'odds': False,
#                             'players': True,
#                             'predictions': True,
#                             'standings': True,
#                             'top_assists': True,
#                             'top_cards': True,
#                             'top_scorers': True},
#                'current': False,
#                'end': '2019-05-24',
#                'start': '2018-08-10',
#                'year': 2018},
#               {'coverage': {'fixtures': {'events': True,
#                                          'lineups': True,
#                                          'statistics_fixtures': True,
#                                          'statistics_players': True},
#                             'injuries': False,
#                             'odds': False,
#                             'players': True,
#                             'predictions': True,
#                             'standings': True,
#                             'top_assists': True,
#                             'top_cards': True,
#                             'top_scorers': True},
#                'current': False,
#                'end': '2020-05-23',
#                'start': '2019-08-09',
#                'year': 2019},
#               {'coverage': {'fixtures': {'events': True,
#                                          'lineups': True,
#                                          'statistics_fixtures': True,
#                                          'statistics_players': True},
#                             'injuries': True,
#                             'odds': False,
#                             'players': True,
#                             'predictions': True,
#                             'standings': True,
#                             'top_assists': True,
#                             'top_cards': True,
#                             'top_scorers': True},
#                'current': False,
#                'end': '2021-05-30',
#                'start': '2020-08-21',
#                'year': 2020},
#               {'coverage': {'fixtures': {'events': True,
#                                          'lineups': True,
#                                          'statistics_fixtures': True,
#                                          'statistics_players': True},
#                             'injuries': True,
#                             'odds': False,
#                             'players': True,
#                             'predictions': True,
#                             'standings': True,
#                             'top_assists': True,
#                             'top_cards': True,
#                             'top_scorers': True},
#                'current': False,
#                'end': '2022-05-29',
#                'start': '2021-08-06',
#                'year': 2021},
#               {'coverage': {'fixtures': {'events': True,
#                                          'lineups': True,
#                                          'statistics_fixtures': True,
#                                          'statistics_players': True},
#                             'injuries': True,
#                             'odds': False,
#                             'players': True,
#                             'predictions': True,
#                             'standings': True,
#                             'top_assists': True,
#                             'top_cards': True,
#                             'top_scorers': True},
#                'current': False,
#                'end': '2023-06-03',
#                'start': '2022-08-05',
#                'year': 2022},
#               {'coverage': {'fixtures': {'events': True,
#                                          'lineups': True,
#                                          'statistics_fixtures': True,
#                                          'statistics_players': True},
#                             'injuries': True,
#                             'odds': False,
#                             'players': True,
#                             'predictions': True,
#                             'standings': True,
#                             'top_assists': True,
#                             'top_cards': True,
#                             'top_scorers': True},
#                'current': False,
#                'end': '2024-06-02',
#                'start': '2023-08-11',
#                'year': 2023},
#               {'coverage': {'fixtures': {'events': True,
#                                          'lineups': True,
#                                          'statistics_fixtures': True,
#                                          'statistics_players': True},
#                             'injuries': True,
#                             'odds': True,
#                             'players': True,
#                             'predictions': True,
#                             'standings': True,
#                             'top_assists': True,
#                             'top_cards': True,
#                             'top_scorers': True},
#                'current': True,
#                'end': '2025-05-18',
#                'start': '2024-08-18',
#                'year': 2024}]}]

# %%
print(f"{'League Name':<{30}} | {'League ID':<{10}}")
print('-' * (50))  # +3 for the separator and padding
for elem in data["response"]:
    if (elem['country']['name']) == 'France':
        name = elem['league']['name']
        league_id = elem['league']['id']
        print(f"{name:<{30}} | {league_id:<{10}}")
# Out:
# League Name                    | League ID
# --------------------------------------------------
# Ligue 1                        | 61
# Ligue 2                        | 62
# National 1                     | 63
# Coupe de France                | 66
# Coupe de la Ligue              | 65
# National 2 - Group A           | 67
# National 2 - Group B           | 68
# National 2 - Group C           | 69
# National 2 - Group D           | 70
# Trophée des Champions          | 526
# Feminine Division 1            | 64
# National 3 - Group A           | 461
# National 3 - Group B           | 462
# National 3 - Group C           | 463
# National 3 - Group D           | 464
# National 3 - Group E           | 465
# National 3 - Group F           | 466
# National 3 - Group H           | 467
# National 3 - Group I           | 468
# National 3 - Group J           | 469
# National 3 - Group K           | 470
# National 3 - Group L           | 471
# National 3 - Group M           | 472
# National 3 - Group G           | 1029

# %%
import requests

# Base URL
base_url = "https://v3.football.api-sports.io/standings"

# Query parameters
params = {
    'league': 61,
    'season': 2020
}

# Headers
headers = {
    'x-rapidapi-key': api_key,
    'x-rapidapi-host': 'v3.football.api-sports.io'
}

# Make the GET request
response = requests.get(base_url, headers=headers, params=params)

# Print the JSON response
pprint.pprint(response.json())
# Out:
# {'errors': [],
#  'get': 'standings',
#  'paging': {'current': 1, 'total': 1},
#  'parameters': {'league': '61', 'season': '2020'},
#  'response': [{'league': {'country': 'France',
#                           'flag': 'https://media.api-sports.io/flags/fr.svg',
#                           'id': 61,
#                           'logo': 'https://media.api-sports.io/football/leagues/61.png',
#                           'name': 'Ligue 1',
#                           'season': 2020,
#                           'standings': [[{'all': {'draw': 11,
#                                                   'goals': {'against': 23,
#                                                             'for': 64},
#                                                   'lose': 3,
#                                                   'played': 38,
#                                                   'win': 24},
#                                           'away': {'draw': 4,
#                                                    'goals': {'against': 12,
#                                                              'for': 36},
#                                                    'lose': 1,
#                                                    'played': 19,
#                                                    'win': 14},
#                                           'description': 'Promotion - '
#                                                          'Champions League '
#                                                          '(Group Stage)',
#                                           'form': 'WDWWW',
#                                           'goalsDiff': 41,
#                                           'group': 'Ligue 1',
#                                           'home': {'draw': 7,
#                                                    'goals': {'against': 11,
#                                                              'for': 28},
#                                                    'lose': 2,
#                                                    'played': 19,
#                                                    'win': 10},
#                                           'points': 83,
#                                           'rank': 1,
#                                           'status': 'same',
#                                           'team': {'id': 79,
#                                                    'logo': 'https://media.api-sports.io/football/teams/79.png',
#                                                    'name': 'Lille'},
#                                           'update': '2021-05-26T00:00:00+00:00'},
#                                          {'all': {'draw': 4,
#                                                   'goals': {'against': 28,
#                                                             'for': 86},
#                                                   'lose': 8,
#                                                   'played': 38,
#                                                   'win': 26},
#                                           'away': {'draw': 3,
#                                                    'goals': {'against': 14,
#                                                              'for': 42},
#                                                    'lose': 3,
#                                                    'played': 19,
#                                                    'win': 13},
#                                           'description': 'Promotion - '
#                                                          'Champions League '
#                                                          '(Group Stage)',
#                                           'form': 'WWDWW',
#                                           'goalsDiff': 58,
#                                           'group': 'Ligue 1',
#                                           'home': {'draw': 1,
#                                                    'goals': {'against': 14,
#                                                              'for': 44},
#                                                    'lose': 5,
#                                                    'played': 19,
#                                                    'win': 13},
#                                           'points': 82,
#                                           'rank': 2,
#                                           'status': 'same',
#                                           'team': {'id': 85,
#                                                    'logo': 'https://media.api-sports.io/football/teams/85.png',
#                                                    'name': 'Paris Saint '
#                                                            'Germain'},
#                                           'update': '2021-05-26T00:00:00+00:00'},
#                                          {'all': {'draw': 6,
#                                                   'goals': {'against': 42,
#                                                             'for': 76},
#                                                   'lose': 8,
#                                                   'played': 38,
#                                                   'win': 24},
#                                           'away': {'draw': 1,
#                                                    'goals': {'against': 21,
#                                                              'for': 33},
#                                                    'lose': 6,
#                                                    'played': 19,
#                                                    'win': 12},
#                                           'description': 'Promotion - '
#                                                          'Champions League '
#                                                          '(Qualification)',
#                                           'form': 'DWWLW',
#                                           'goalsDiff': 34,
#                                           'group': 'Ligue 1',
#                                           'home': {'draw': 5,
#                                                    'goals': {'against': 21,
#                                                              'for': 43},
#                                                    'lose': 2,
#                                                    'played': 19,
#                                                    'win': 12},
#                                           'points': 78,
#                                           'rank': 3,
#                                           'status': 'same',
#                                           'team': {'id': 91,
#                                                    'logo': 'https://media.api-sports.io/football/teams/91.png',
#                                                    'name': 'Monaco'},
#                                           'update': '2021-05-26T00:00:00+00:00'},
#                                          {'all': {'draw': 10,
#                                                   'goals': {'against': 43,
#                                                             'for': 81},
#                                                   'lose': 6,
#                                                   'played': 38,
#                                                   'win': 22},
#                                           'away': {'draw': 7,
#                                                    'goals': {'against': 20,
#                                                              'for': 39},
#                                                    'lose': 1,
#                                                    'played': 19,
#                                                    'win': 11},
#                                           'description': 'Promotion - Europa '
#                                                          'League (Group Stage)',
#                                           'form': 'LWWWL',
#                                           'goalsDiff': 38,
#                                           'group': 'Ligue 1',
#                                           'home': {'draw': 3,
#                                                    'goals': {'against': 23,
#                                                              'for': 42},
#                                                    'lose': 5,
#                                                    'played': 19,
#                                                    'win': 11},
#                                           'points': 76,
#                                           'rank': 4,
#                                           'status': 'same',
#                                           'team': {'id': 80,
#                                                    'logo': 'https://media.api-sports.io/football/teams/80.png',
#                                                    'name': 'Lyon'},
#                                           'update': '2021-05-26T00:00:00+00:00'},
#                                          {'all': {'draw': 12,
#                                                   'goals': {'against': 47,
#                                                             'for': 54},
#                                                   'lose': 10,
#                                                   'played': 38,
#                                                   'win': 16},
#                                           'away': {'draw': 7,
#                                                    'goals': {'against': 24,
#                                                              'for': 22},
#                                                    'lose': 6,
#                                                    'played': 19,
#                                                    'win': 6},
#                                           'description': 'Promotion - Europa '
#                                                          'League (Group Stage)',
#                                           'form': 'DWLDW',
#                                           'goalsDiff': 7,
#                                           'group': 'Ligue 1',
#                                           'home': {'draw': 5,
#                                                    'goals': {'against': 23,
#                                                              'for': 32},
#                                                    'lose': 4,
#                                                    'played': 19,
#                                                    'win': 10},
#                                           'points': 60,
#                                           'rank': 5,
#                                           'status': 'same',
#                                           'team': {'id': 81,
#                                                    'logo': 'https://media.api-sports.io/football/teams/81.png',
#                                                    'name': 'Marseille'},
#                                           'update': '2021-05-26T00:00:00+00:00'},
#                                          {'all': {'draw': 10,
#                                                   'goals': {'against': 40,
#                                                             'for': 52},
#                                                   'lose': 12,
#                                                   'played': 38,
#                                                   'win': 16},
#                                           'away': {'draw': 6,
#                                                    'goals': {'against': 19,
#                                                              'for': 26},
#                                                    'lose': 6,
#                                                    'played': 19,
#                                                    'win': 7},
#                                           'description': 'Promotion - Europa '
#                                                          'Conference League '
#                                                          '(Qualification)',
#                                           'form': 'WLDLW',
#                                           'goalsDiff': 12,
#                                           'group': 'Ligue 1',
#                                           'home': {'draw': 4,
#                                                    'goals': {'against': 21,
#                                                              'for': 26},
#                                                    'lose': 6,
#                                                    'played': 19,
#                                                    'win': 9},
#                                           'points': 58,
#                                           'rank': 6,
#                                           'status': 'same',
#                                           'team': {'id': 94,
#                                                    'logo': 'https://media.api-sports.io/football/teams/94.png',
#                                                    'name': 'Rennes'},
#                                           'update': '2021-05-26T00:00:00+00:00'},
#                                          {'all': {'draw': 12,
#                                                   'goals': {'against': 54,
#                                                             'for': 55},
#                                                   'lose': 11,
#                                                   'played': 38,
#                                                   'win': 15},
#                                           'away': {'draw': 5,
#                                                    'goals': {'against': 28,
#                                                              'for': 27},
#                                                    'lose': 6,
#                                                    'played': 19,
#                                                    'win': 8},
#                                           'description': None,
#                                           'form': 'DLLLW',
#                                           'goalsDiff': 1,
#                                           'group': 'Ligue 1',
#                                           'home': {'draw': 7,
#                                                    'goals': {'against': 26,
#                                                              'for': 28},
#                                                    'lose': 5,
#                                                    'played': 19,
#                                                    'win': 7},
#                                           'points': 57,
#                                           'rank': 7,
#                                           'status': 'same',
#                                           'team': {'id': 116,
#                                                    'logo': 'https://media.api-sports.io/football/teams/116.png',
#                                                    'name': 'Lens'},
#                                           'update': '2021-05-26T00:00:00+00:00'},
#                                          {'all': {'draw': 12,
#                                                   'goals': {'against': 62,
#                                                             'for': 60},
#                                                   'lose': 12,
#                                                   'played': 38,
#                                                   'win': 14},
#                                           'away': {'draw': 8,
#                                                    'goals': {'against': 27,
#                                                              'for': 26},
#                                                    'lose': 4,
#                                                    'played': 19,
#                                                    'win': 7},
#                                           'description': None,
#                                           'form': 'WDWLL',
#                                           'goalsDiff': -2,
#                                           'group': 'Ligue 1',
#                                           'home': {'draw': 4,
#                                                    'goals': {'against': 35,
#                                                              'for': 34},
#                                                    'lose': 8,
#                                                    'played': 19,
#                                                    'win': 7},
#                                           'points': 54,
#                                           'rank': 8,
#                                           'status': 'same',
#                                           'team': {'id': 82,
#                                                    'logo': 'https://media.api-sports.io/football/teams/82.png',
#                                                    'name': 'Montpellier'},
#                                           'update': '2021-05-26T00:00:00+00:00'},
#                                          {'all': {'draw': 7,
#                                                   'goals': {'against': 53,
#                                                             'for': 50},
#                                                   'lose': 16,
#                                                   'played': 38,
#                                                   'win': 15},
#                                           'away': {'draw': 4,
#                                                    'goals': {'against': 23,
#                                                              'for': 25},
#                                                    'lose': 7,
#                                                    'played': 19,
#                                                    'win': 8},
#                                           'description': None,
#                                           'form': 'WLWLW',
#                                           'goalsDiff': -3,
#                                           'group': 'Ligue 1',
#                                           'home': {'draw': 3,
#                                                    'goals': {'against': 30,
#                                                              'for': 25},
#                                                    'lose': 9,
#                                                    'played': 19,
#                                                    'win': 7},
#                                           'points': 52,
#                                           'rank': 9,
#                                           'status': 'same',
#                                           'team': {'id': 84,
#                                                    'logo': 'https://media.api-sports.io/football/teams/84.png',
#                                                    'name': 'Nice'},
#                                           'update': '2021-05-26T00:00:00+00:00'},
#                                          {'all': {'draw': 11,
#                                                   'goals': {'against': 48,
#                                                             'for': 44},
#                                                   'lose': 15,
#                                                   'played': 38,
#                                                   'win': 12},
#                                           'away': {'draw': 6,
#                                                    'goals': {'against': 22,
#                                                              'for': 25},
#                                                    'lose': 6,
#                                                    'played': 19,
#                                                    'win': 7},
#                                           'description': None,
#                                           'form': 'DLLWL',
#                                           'goalsDiff': -4,
#                                           'group': 'Ligue 1',
#                                           'home': {'draw': 5,
#                                                    'goals': {'against': 26,
#                                                              'for': 19},
#                                                    'lose': 9,
#                                                    'played': 19,
#                                                    'win': 5},
#                                           'points': 47,
#                                           'rank': 10,
#                                           'status': 'same',
#                                           'team': {'id': 112,
#                                                    'logo': 'https://media.api-sports.io/football/teams/112.png',
#                                                    'name': 'Metz'},
#                                           'update': '2021-05-26T00:00:00+00:00'},
#                                          {'all': {'draw': 10,
#                                                   'goals': {'against': 54,
#                                                             'for': 42},
#                                                   'lose': 16,
#                                                   'played': 38,
#                                                   'win': 12},
#                                           'away': {'draw': 4,
#                                                    'goals': {'against': 25,
#                                                              'for': 22},
#                                                    'lose': 8,
#                                                    'played': 19,
#                                                    'win': 7},
#                                           'description': None,
#                                           'form': 'LDWWL',
#                                           'goalsDiff': -12,
#                                           'group': 'Ligue 1',
#                                           'home': {'draw': 6,
#                                                    'goals': {'against': 29,
#                                                              'for': 20},
#                                                    'lose': 8,
#                                                    'played': 19,
#                                                    'win': 5},
#                                           'points': 46,
#                                           'rank': 11,
#                                           'status': 'same',
#                                           'team': {'id': 1063,
#                                                    'logo': 'https://media.api-sports.io/football/teams/1063.png',
#                                                    'name': 'Saint Etienne'},
#                                           'update': '2021-05-26T00:00:00+00:00'},
#                                          {'all': {'draw': 6,
#                                                   'goals': {'against': 56,
#                                                             'for': 42},
#                                                   'lose': 19,
#                                                   'played': 38,
#                                                   'win': 13},
#                                           'away': {'draw': 2,
#                                                    'goals': {'against': 35,
#                                                              'for': 23},
#                                                    'lose': 11,
#                                                    'played': 19,
#                                                    'win': 6},
#                                           'description': None,
#                                           'form': 'WWLWL',
#                                           'goalsDiff': -14,
#                                           'group': 'Ligue 1',
#                                           'home': {'draw': 4,
#                                                    'goals': {'against': 21,
#                                                              'for': 19},
#                                                    'lose': 8,
#                                                    'played': 19,
#                                                    'win': 7},
#                                           'points': 45,
#                                           'rank': 12,
#                                           'status': 'same',
#                                           'team': {'id': 78,
#                                                    'logo': 'https://media.api-sports.io/football/teams/78.png',
#                                                    'name': 'Bordeaux'},
#                                           'update': '2021-05-26T00:00:00+00:00'},
#                                          {'all': {'draw': 8,
#                                                   'goals': {'against': 58,
#                                                             'for': 40},
#                                                   'lose': 18,
#                                                   'played': 38,
#                                                   'win': 12},
#                                           'away': {'draw': 5,
#                                                    'goals': {'against': 31,
#                                                              'for': 20},
#                                                    'lose': 8,
#                                                    'played': 19,
#                                                    'win': 6},
#                                           'description': None,
#                                           'form': 'LLWLL',
#                                           'goalsDiff': -18,
#                                           'group': 'Ligue 1',
#                                           'home': {'draw': 3,
#                                                    'goals': {'against': 27,
#                                                              'for': 20},
#                                                    'lose': 10,
#                                                    'played': 19,
#                                                    'win': 6},
#                                           'points': 44,
#                                           'rank': 13,
#                                           'status': 'same',
#                                           'team': {'id': 77,
#                                                    'logo': 'https://media.api-sports.io/football/teams/77.png',
#                                                    'name': 'Angers'},
#                                           'update': '2021-05-26T00:00:00+00:00'},
#                                          {'all': {'draw': 15,
#                                                   'goals': {'against': 50,
#                                                             'for': 42},
#                                                   'lose': 14,
#                                                   'played': 38,
#                                                   'win': 9},
#                                           'away': {'draw': 7,
#                                                    'goals': {'against': 29,
#                                                              'for': 26},
#                                                    'lose': 7,
#                                                    'played': 19,
#                                                    'win': 5},
#                                           'description': None,
#                                           'form': 'LLLDL',
#                                           'goalsDiff': -8,
#                                           'group': 'Ligue 1',
#                                           'home': {'draw': 8,
#                                                    'goals': {'against': 21,
#                                                              'for': 16},
#                                                    'lose': 7,
#                                                    'played': 19,
#                                                    'win': 4},
#                                           'points': 42,
#                                           'rank': 14,
#                                           'status': 'same',
#                                           'team': {'id': 93,
#                                                    'logo': 'https://media.api-sports.io/football/teams/93.png',
#                                                    'name': 'Reims'},
#                                           'update': '2021-05-26T00:00:00+00:00'},
#                                          {'all': {'draw': 9,
#                                                   'goals': {'against': 58,
#                                                             'for': 49},
#                                                   'lose': 18,
#                                                   'played': 38,
#                                                   'win': 11},
#                                           'away': {'draw': 4,
#                                                    'goals': {'against': 29,
#                                                              'for': 28},
#                                                    'lose': 8,
#                                                    'played': 19,
#                                                    'win': 7},
#                                           'description': None,
#                                           'form': 'DWLDL',
#                                           'goalsDiff': -9,
#                                           'group': 'Ligue 1',
#                                           'home': {'draw': 5,
#                                                    'goals': {'against': 29,
#                                                              'for': 21},
#                                                    'lose': 10,
#                                                    'played': 19,
#                                                    'win': 4},
#                                           'points': 42,
#                                           'rank': 15,
#                                           'status': 'same',
#                                           'team': {'id': 95,
#                                                    'logo': 'https://media.api-sports.io/football/teams/95.png',
#                                                    'name': 'Strasbourg'},
#                                           'update': '2021-05-26T00:00:00+00:00'},
#                                          {'all': {'draw': 9,
#                                                   'goals': {'against': 68,
#                                                             'for': 50},
#                                                   'lose': 18,
#                                                   'played': 38,
#                                                   'win': 11},
#                                           'away': {'draw': 7,
#                                                    'goals': {'against': 39,
#                                                              'for': 19},
#                                                    'lose': 11,
#                                                    'played': 19,
#                                                    'win': 1},
#                                           'description': None,
#                                           'form': 'DWLWW',
#                                           'goalsDiff': -18,
#                                           'group': 'Ligue 1',
#                                           'home': {'draw': 2,
#                                                    'goals': {'against': 29,
#                                                              'for': 31},
#                                                    'lose': 7,
#                                                    'played': 19,
#                                                    'win': 10},
#                                           'points': 42,
#                                           'rank': 16,
#                                           'status': 'same',
#                                           'team': {'id': 97,
#                                                    'logo': 'https://media.api-sports.io/football/teams/97.png',
#                                                    'name': 'Lorient'},
#                                           'update': '2021-05-26T00:00:00+00:00'},
#                                          {'all': {'draw': 8,
#                                                   'goals': {'against': 66,
#                                                             'for': 50},
#                                                   'lose': 19,
#                                                   'played': 38,
#                                                   'win': 11},
#                                           'away': {'draw': 4,
#                                                    'goals': {'against': 33,
#                                                              'for': 18},
#                                                    'lose': 12,
#                                                    'played': 19,
#                                                    'win': 3},
#                                           'description': None,
#                                           'form': 'LDLLW',
#                                           'goalsDiff': -16,
#                                           'group': 'Ligue 1',
#                                           'home': {'draw': 4,
#                                                    'goals': {'against': 33,
#                                                              'for': 32},
#                                                    'lose': 7,
#                                                    'played': 19,
#                                                    'win': 8},
#                                           'points': 41,
#                                           'rank': 17,
#                                           'status': 'same',
#                                           'team': {'id': 106,
#                                                    'logo': 'https://media.api-sports.io/football/teams/106.png',
#                                                    'name': 'Stade Brestois 29'},
#                                           'update': '2021-05-26T00:00:00+00:00'},
#                                          {'all': {'draw': 13,
#                                                   'goals': {'against': 55,
#                                                             'for': 47},
#                                                   'lose': 16,
#                                                   'played': 38,
#                                                   'win': 9},
#                                           'away': {'draw': 5,
#                                                    'goals': {'against': 26,
#                                                              'for': 26},
#                                                    'lose': 8,
#                                                    'played': 19,
#                                                    'win': 6},
#                                           'description': 'Ligue 1 (Relegation)',
#                                           'form': 'LWWWW',
#                                           'goalsDiff': -8,
#                                           'group': 'Ligue 1',
#                                           'home': {'draw': 8,
#                                                    'goals': {'against': 29,
#                                                              'for': 21},
#                                                    'lose': 8,
#                                                    'played': 19,
#                                                    'win': 3},
#                                           'points': 40,
#                                           'rank': 18,
#                                           'status': 'same',
#                                           'team': {'id': 83,
#                                                    'logo': 'https://media.api-sports.io/football/teams/83.png',
#                                                    'name': 'Nantes'},
#                                           'update': '2021-05-26T00:00:00+00:00'},
#                                          {'all': {'draw': 8,
#                                                   'goals': {'against': 71,
#                                                             'for': 40},
#                                                   'lose': 21,
#                                                   'played': 38,
#                                                   'win': 9},
#                                           'away': {'draw': 3,
#                                                    'goals': {'against': 32,
#                                                              'for': 18},
#                                                    'lose': 10,
#                                                    'played': 19,
#                                                    'win': 6},
#                                           'description': 'Relegation - Ligue 2',
#                                           'form': 'LLWDL',
#                                           'goalsDiff': -31,
#                                           'group': 'Ligue 1',
#                                           'home': {'draw': 5,
#                                                    'goals': {'against': 39,
#                                                              'for': 22},
#                                                    'lose': 11,
#                                                    'played': 19,
#                                                    'win': 3},
#                                           'points': 35,
#                                           'rank': 19,
#                                           'status': 'same',
#                                           'team': {'id': 92,
#                                                    'logo': 'https://media.api-sports.io/football/teams/92.png',
#                                                    'name': 'Nimes'},
#                                           'update': '2021-05-26T00:00:00+00:00'},
#                                          {'all': {'draw': 9,
#                                                   'goals': {'against': 73,
#                                                             'for': 25},
#                                                   'lose': 25,
#                                                   'played': 38,
#                                                   'win': 4},
#                                           'away': {'draw': 3,
#                                                    'goals': {'against': 42,
#                                                              'for': 17},
#                                                    'lose': 13,
#                                                    'played': 19,
#                                                    'win': 3},
#                                           'description': 'Relegation - Ligue 2',
#                                           'form': 'WLLLL',
#                                           'goalsDiff': -48,
#                                           'group': 'Ligue 1',
#                                           'home': {'draw': 6,
#                                                    'goals': {'against': 31,
#                                                              'for': 8},
#                                                    'lose': 12,
#                                                    'played': 19,
#                                                    'win': 1},
#                                           'points': 21,
#                                           'rank': 20,
#                                           'status': 'same',
#                                           'team': {'id': 89,
#                                                    'logo': 'https://media.api-sports.io/football/teams/89.png',
#                                                    'name': 'Dijon'},
#                                           'update': '2021-05-26T00:00:00+00:00'}]]}}],
#  'results': 1}

# %%
ranking_by_team = response.json()['response'][0]['league']['standings'][0]
ranking_by_team
# Out:
# [{'rank': 1,
#   'team': {'id': 79,
#    'name': 'Lille',
#    'logo': 'https://media.api-sports.io/football/teams/79.png'},
#   'points': 83,
#   'goalsDiff': 41,
#   'group': 'Ligue 1',
#   'form': 'WDWWW',
#   'status': 'same',
#   'description': 'Promotion - Champions League (Group Stage)',
#   'all': {'played': 38,
#    'win': 24,
#    'draw': 11,
#    'lose': 3,
#    'goals': {'for': 64, 'against': 23}},
#   'home': {'played': 19,
#    'win': 10,
#    'draw': 7,
#    'lose': 2,
#    'goals': {'for': 28, 'against': 11}},
#   'away': {'played': 19,
#    'win': 14,
#    'draw': 4,
#    'lose': 1,
#    'goals': {'for': 36, 'against': 12}},
#   'update': '2021-05-26T00:00:00+00:00'},
#  {'rank': 2,
#   'team': {'id': 85,
#    'name': 'Paris Saint Germain',
#    'logo': 'https://media.api-sports.io/football/teams/85.png'},
#   'points': 82,
#   'goalsDiff': 58,
#   'group': 'Ligue 1',
#   'form': 'WWDWW',
#   'status': 'same',
#   'description': 'Promotion - Champions League (Group Stage)',
#   'all': {'played': 38,
#    'win': 26,
#    'draw': 4,
#    'lose': 8,
#    'goals': {'for': 86, 'against': 28}},
#   'home': {'played': 19,
#    'win': 13,
#    'draw': 1,
#    'lose': 5,
#    'goals': {'for': 44, 'against': 14}},
#   'away': {'played': 19,
#    'win': 13,
#    'draw': 3,
#    'lose': 3,
#    'goals': {'for': 42, 'against': 14}},
#   'update': '2021-05-26T00:00:00+00:00'},
#  {'rank': 3,
#   'team': {'id': 91,
#    'name': 'Monaco',
#    'logo': 'https://media.api-sports.io/football/teams/91.png'},
#   'points': 78,
#   'goalsDiff': 34,
#   'group': 'Ligue 1',
#   'form': 'DWWLW',
#   'status': 'same',
#   'description': 'Promotion - Champions League (Qualification)',
#   'all': {'played': 38,
#    'win': 24,
#    'draw': 6,
#    'lose': 8,
#    'goals': {'for': 76, 'against': 42}},
#   'home': {'played': 19,
#    'win': 12,
#    'draw': 5,
#    'lose': 2,
#    'goals': {'for': 43, 'against': 21}},
#   'away': {'played': 19,
#    'win': 12,
#    'draw': 1,
#    'lose': 6,
#    'goals': {'for': 33, 'against': 21}},
#   'update': '2021-05-26T00:00:00+00:00'},
#  {'rank': 4,
#   'team': {'id': 80,
#    'name': 'Lyon',
#    'logo': 'https://media.api-sports.io/football/teams/80.png'},
#   'points': 76,
#   'goalsDiff': 38,
#   'group': 'Ligue 1',
#   'form': 'LWWWL',
#   'status': 'same',
#   'description': 'Promotion - Europa League (Group Stage)',
#   'all': {'played': 38,
#    'win': 22,
#    'draw': 10,
#    'lose': 6,
#    'goals': {'for': 81, 'against': 43}},
#   'home': {'played': 19,
#    'win': 11,
#    'draw': 3,
#    'lose': 5,
#    'goals': {'for': 42, 'against': 23}},
#   'away': {'played': 19,
#    'win': 11,
#    'draw': 7,
#    'lose': 1,
#    'goals': {'for': 39, 'against': 20}},
#   'update': '2021-05-26T00:00:00+00:00'},
#  {'rank': 5,
#   'team': {'id': 81,
#    'name': 'Marseille',
#    'logo': 'https://media.api-sports.io/football/teams/81.png'},
#   'points': 60,
#   'goalsDiff': 7,
#   'group': 'Ligue 1',
#   'form': 'DWLDW',
#   'status': 'same',
#   'description': 'Promotion - Europa League (Group Stage)',
#   'all': {'played': 38,
#    'win': 16,
#    'draw': 12,
#    'lose': 10,
#    'goals': {'for': 54, 'against': 47}},
#   'home': {'played': 19,
#    'win': 10,
#    'draw': 5,
#    'lose': 4,
#    'goals': {'for': 32, 'against': 23}},
#   'away': {'played': 19,
#    'win': 6,
#    'draw': 7,
#    'lose': 6,
#    'goals': {'for': 22, 'against': 24}},
#   'update': '2021-05-26T00:00:00+00:00'},
#  {'rank': 6,
#   'team': {'id': 94,
#    'name': 'Rennes',
#    'logo': 'https://media.api-sports.io/football/teams/94.png'},
#   'points': 58,
#   'goalsDiff': 12,
#   'group': 'Ligue 1',
#   'form': 'WLDLW',
#   'status': 'same',
#   'description': 'Promotion - Europa Conference League (Qualification)',
#   'all': {'played': 38,
#    'win': 16,
#    'draw': 10,
#    'lose': 12,
#    'goals': {'for': 52, 'against': 40}},
#   'home': {'played': 19,
#    'win': 9,
#    'draw': 4,
#    'lose': 6,
#    'goals': {'for': 26, 'against': 21}},
#   'away': {'played': 19,
#    'win': 7,
#    'draw': 6,
#    'lose': 6,
#    'goals': {'for': 26, 'against': 19}},
#   'update': '2021-05-26T00:00:00+00:00'},
#  {'rank': 7,
#   'team': {'id': 116,
#    'name': 'Lens',
#    'logo': 'https://media.api-sports.io/football/teams/116.png'},
#   'points': 57,
#   'goalsDiff': 1,
#   'group': 'Ligue 1',
#   'form': 'DLLLW',
#   'status': 'same',
#   'description': None,
#   'all': {'played': 38,
#    'win': 15,
#    'draw': 12,
#    'lose': 11,
#    'goals': {'for': 55, 'against': 54}},
#   'home': {'played': 19,
#    'win': 7,
#    'draw': 7,
#    'lose': 5,
#    'goals': {'for': 28, 'against': 26}},
#   'away': {'played': 19,
#    'win': 8,
#    'draw': 5,
#    'lose': 6,
#    'goals': {'for': 27, 'against': 28}},
#   'update': '2021-05-26T00:00:00+00:00'},
#  {'rank': 8,
#   'team': {'id': 82,
#    'name': 'Montpellier',
#    'logo': 'https://media.api-sports.io/football/teams/82.png'},
#   'points': 54,
#   'goalsDiff': -2,
#   'group': 'Ligue 1',
#   'form': 'WDWLL',
#   'status': 'same',
#   'description': None,
#   'all': {'played': 38,
#    'win': 14,
#    'draw': 12,
#    'lose': 12,
#    'goals': {'for': 60, 'against': 62}},
#   'home': {'played': 19,
#    'win': 7,
#    'draw': 4,
#    'lose': 8,
#    'goals': {'for': 34, 'against': 35}},
#   'away': {'played': 19,
#    'win': 7,
#    'draw': 8,
#    'lose': 4,
#    'goals': {'for': 26, 'against': 27}},
#   'update': '2021-05-26T00:00:00+00:00'},
#  {'rank': 9,
#   'team': {'id': 84,
#    'name': 'Nice',
#    'logo': 'https://media.api-sports.io/football/teams/84.png'},
#   'points': 52,
#   'goalsDiff': -3,
#   'group': 'Ligue 1',
#   'form': 'WLWLW',
#   'status': 'same',
#   'description': None,
#   'all': {'played': 38,
#    'win': 15,
#    'draw': 7,
#    'lose': 16,
#    'goals': {'for': 50, 'against': 53}},
#   'home': {'played': 19,
#    'win': 7,
#    'draw': 3,
#    'lose': 9,
#    'goals': {'for': 25, 'against': 30}},
#   'away': {'played': 19,
#    'win': 8,
#    'draw': 4,
#    'lose': 7,
#    'goals': {'for': 25, 'against': 23}},
#   'update': '2021-05-26T00:00:00+00:00'},
#  {'rank': 10,
#   'team': {'id': 112,
#    'name': 'Metz',
#    'logo': 'https://media.api-sports.io/football/teams/112.png'},
#   'points': 47,
#   'goalsDiff': -4,
#   'group': 'Ligue 1',
#   'form': 'DLLWL',
#   'status': 'same',
#   'description': None,
#   'all': {'played': 38,
#    'win': 12,
#    'draw': 11,
#    'lose': 15,
#    'goals': {'for': 44, 'against': 48}},
#   'home': {'played': 19,
#    'win': 5,
#    'draw': 5,
#    'lose': 9,
#    'goals': {'for': 19, 'against': 26}},
#   'away': {'played': 19,
#    'win': 7,
#    'draw': 6,
#    'lose': 6,
#    'goals': {'for': 25, 'against': 22}},
#   'update': '2021-05-26T00:00:00+00:00'},
#  {'rank': 11,
#   'team': {'id': 1063,
#    'name': 'Saint Etienne',
#    'logo': 'https://media.api-sports.io/football/teams/1063.png'},
#   'points': 46,
#   'goalsDiff': -12,
#   'group': 'Ligue 1',
#   'form': 'LDWWL',
#   'status': 'same',
#   'description': None,
#   'all': {'played': 38,
#    'win': 12,
#    'draw': 10,
#    'lose': 16,
#    'goals': {'for': 42, 'against': 54}},
#   'home': {'played': 19,
#    'win': 5,
#    'draw': 6,
#    'lose': 8,
#    'goals': {'for': 20, 'against': 29}},
#   'away': {'played': 19,
#    'win': 7,
#    'draw': 4,
#    'lose': 8,
#    'goals': {'for': 22, 'against': 25}},
#   'update': '2021-05-26T00:00:00+00:00'},
#  {'rank': 12,
#   'team': {'id': 78,
#    'name': 'Bordeaux',
#    'logo': 'https://media.api-sports.io/football/teams/78.png'},
#   'points': 45,
#   'goalsDiff': -14,
#   'group': 'Ligue 1',
#   'form': 'WWLWL',
#   'status': 'same',
#   'description': None,
#   'all': {'played': 38,
#    'win': 13,
#    'draw': 6,
#    'lose': 19,
#    'goals': {'for': 42, 'against': 56}},
#   'home': {'played': 19,
#    'win': 7,
#    'draw': 4,
#    'lose': 8,
#    'goals': {'for': 19, 'against': 21}},
#   'away': {'played': 19,
#    'win': 6,
#    'draw': 2,
#    'lose': 11,
#    'goals': {'for': 23, 'against': 35}},
#   'update': '2021-05-26T00:00:00+00:00'},
#  {'rank': 13,
#   'team': {'id': 77,
#    'name': 'Angers',
#    'logo': 'https://media.api-sports.io/football/teams/77.png'},
#   'points': 44,
#   'goalsDiff': -18,
#   'group': 'Ligue 1',
#   'form': 'LLWLL',
#   'status': 'same',
#   'description': None,
#   'all': {'played': 38,
#    'win': 12,
#    'draw': 8,
#    'lose': 18,
#    'goals': {'for': 40, 'against': 58}},
#   'home': {'played': 19,
#    'win': 6,
#    'draw': 3,
#    'lose': 10,
#    'goals': {'for': 20, 'against': 27}},
#   'away': {'played': 19,
#    'win': 6,
#    'draw': 5,
#    'lose': 8,
#    'goals': {'for': 20, 'against': 31}},
#   'update': '2021-05-26T00:00:00+00:00'},
#  {'rank': 14,
#   'team': {'id': 93,
#    'name': 'Reims',
#    'logo': 'https://media.api-sports.io/football/teams/93.png'},
#   'points': 42,
#   'goalsDiff': -8,
#   'group': 'Ligue 1',
#   'form': 'LLLDL',
#   'status': 'same',
#   'description': None,
#   'all': {'played': 38,
#    'win': 9,
#    'draw': 15,
#    'lose': 14,
#    'goals': {'for': 42, 'against': 50}},
#   'home': {'played': 19,
#    'win': 4,
#    'draw': 8,
#    'lose': 7,
#    'goals': {'for': 16, 'against': 21}},
#   'away': {'played': 19,
#    'win': 5,
#    'draw': 7,
#    'lose': 7,
#    'goals': {'for': 26, 'against': 29}},
#   'update': '2021-05-26T00:00:00+00:00'},
#  {'rank': 15,
#   'team': {'id': 95,
#    'name': 'Strasbourg',
#    'logo': 'https://media.api-sports.io/football/teams/95.png'},
#   'points': 42,
#   'goalsDiff': -9,
#   'group': 'Ligue 1',
#   'form': 'DWLDL',
#   'status': 'same',
#   'description': None,
#   'all': {'played': 38,
#    'win': 11,
#    'draw': 9,
#    'lose': 18,
#    'goals': {'for': 49, 'against': 58}},
#   'home': {'played': 19,
#    'win': 4,
#    'draw': 5,
#    'lose': 10,
#    'goals': {'for': 21, 'against': 29}},
#   'away': {'played': 19,
#    'win': 7,
#    'draw': 4,
#    'lose': 8,
#    'goals': {'for': 28, 'against': 29}},
#   'update': '2021-05-26T00:00:00+00:00'},
#  {'rank': 16,
#   'team': {'id': 97,
#    'name': 'Lorient',
#    'logo': 'https://media.api-sports.io/football/teams/97.png'},
#   'points': 42,
#   'goalsDiff': -18,
#   'group': 'Ligue 1',
#   'form': 'DWLWW',
#   'status': 'same',
#   'description': None,
#   'all': {'played': 38,
#    'win': 11,
#    'draw': 9,
#    'lose': 18,
#    'goals': {'for': 50, 'against': 68}},
#   'home': {'played': 19,
#    'win': 10,
#    'draw': 2,
#    'lose': 7,
#    'goals': {'for': 31, 'against': 29}},
#   'away': {'played': 19,
#    'win': 1,
#    'draw': 7,
#    'lose': 11,
#    'goals': {'for': 19, 'against': 39}},
#   'update': '2021-05-26T00:00:00+00:00'},
#  {'rank': 17,
#   'team': {'id': 106,
#    'name': 'Stade Brestois 29',
#    'logo': 'https://media.api-sports.io/football/teams/106.png'},
#   'points': 41,
#   'goalsDiff': -16,
#   'group': 'Ligue 1',
#   'form': 'LDLLW',
#   'status': 'same',
#   'description': None,
#   'all': {'played': 38,
#    'win': 11,
#    'draw': 8,
#    'lose': 19,
#    'goals': {'for': 50, 'against': 66}},
#   'home': {'played': 19,
#    'win': 8,
#    'draw': 4,
#    'lose': 7,
#    'goals': {'for': 32, 'against': 33}},
#   'away': {'played': 19,
#    'win': 3,
#    'draw': 4,
#    'lose': 12,
#    'goals': {'for': 18, 'against': 33}},
#   'update': '2021-05-26T00:00:00+00:00'},
#  {'rank': 18,
#   'team': {'id': 83,
#    'name': 'Nantes',
#    'logo': 'https://media.api-sports.io/football/teams/83.png'},
#   'points': 40,
#   'goalsDiff': -8,
#   'group': 'Ligue 1',
#   'form': 'LWWWW',
#   'status': 'same',
#   'description': 'Ligue 1 (Relegation)',
#   'all': {'played': 38,
#    'win': 9,
#    'draw': 13,
#    'lose': 16,
#    'goals': {'for': 47, 'against': 55}},
#   'home': {'played': 19,
#    'win': 3,
#    'draw': 8,
#    'lose': 8,
#    'goals': {'for': 21, 'against': 29}},
#   'away': {'played': 19,
#    'win': 6,
#    'draw': 5,
#    'lose': 8,
#    'goals': {'for': 26, 'against': 26}},
#   'update': '2021-05-26T00:00:00+00:00'},
#  {'rank': 19,
#   'team': {'id': 92,
#    'name': 'Nimes',
#    'logo': 'https://media.api-sports.io/football/teams/92.png'},
#   'points': 35,
#   'goalsDiff': -31,
#   'group': 'Ligue 1',
#   'form': 'LLWDL',
#   'status': 'same',
#   'description': 'Relegation - Ligue 2',
#   'all': {'played': 38,
#    'win': 9,
#    'draw': 8,
#    'lose': 21,
#    'goals': {'for': 40, 'against': 71}},
#   'home': {'played': 19,
#    'win': 3,
#    'draw': 5,
#    'lose': 11,
#    'goals': {'for': 22, 'against': 39}},
#   'away': {'played': 19,
#    'win': 6,
#    'draw': 3,
#    'lose': 10,
#    'goals': {'for': 18, 'against': 32}},
#   'update': '2021-05-26T00:00:00+00:00'},
#  {'rank': 20,
#   'team': {'id': 89,
#    'name': 'Dijon',
#    'logo': 'https://media.api-sports.io/football/teams/89.png'},
#   'points': 21,
#   'goalsDiff': -48,
#   'group': 'Ligue 1',
#   'form': 'WLLLL',
#   'status': 'same',
#   'description': 'Relegation - Ligue 2',
#   'all': {'played': 38,
#    'win': 4,
#    'draw': 9,
#    'lose': 25,
#    'goals': {'for': 25, 'against': 73}},
#   'home': {'played': 19,
#    'win': 1,
#    'draw': 6,
#    'lose': 12,
#    'goals': {'for': 8, 'against': 31}},
#   'away': {'played': 19,
#    'win': 3,
#    'draw': 3,
#    'lose': 13,
#    'goals': {'for': 17, 'against': 42}},
#   'update': '2021-05-26T00:00:00+00:00'}]

# %%
# Define column widths
width_rank = 5
width_name = 20
width_points = 10
width_id = 10

# Print header
print(f"{'Rank':<{width_rank}} | {'Equipe':<{width_name}} | {'Points':>{width_points}} | {'ID':>{width_id}}")

# Print separator
print('-' * (width_rank + width_name + width_points + width_id + 9))  # +9 for the separators and padding

# Print data
for team in ranking_by_team:
    rank = team['rank']
    name = team['team']['name']
    points = team['points']
    team_id = team['team']['id']
    print(f"{rank:<{width_rank}} | {name:<{width_name}} | {points:>{width_points}}pts | {team_id:>{width_id}}")
# Out:
# Rank  | Equipe               |     Points |         ID
# ------------------------------------------------------
# 1     | Lille                |         83pts |         79
# 2     | Paris Saint Germain  |         82pts |         85
# 3     | Monaco               |         78pts |         91
# 4     | Lyon                 |         76pts |         80
# 5     | Marseille            |         60pts |         81
# 6     | Rennes               |         58pts |         94
# 7     | Lens                 |         57pts |        116
# 8     | Montpellier          |         54pts |         82
# 9     | Nice                 |         52pts |         84
# 10    | Metz                 |         47pts |        112
# 11    | Saint Etienne        |         46pts |       1063
# 12    | Bordeaux             |         45pts |         78
# 13    | Angers               |         44pts |         77
# 14    | Reims                |         42pts |         93
# 15    | Strasbourg           |         42pts |         95
# 16    | Lorient              |         42pts |         97
# 17    | Stade Brestois 29    |         41pts |        106
# 18    | Nantes               |         40pts |         83
# 19    | Nimes                |         35pts |         92
# 20    | Dijon                |         21pts |         89

# %% [markdown]
# ## Exercise
#
# ### 1. Whhat is the biggest stadium according to this website?
# ### 2. What is the v stadium in Germany according to this website?
# ### 3. Country with the most seats in stadiums?
