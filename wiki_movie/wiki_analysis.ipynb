# %%
import pandas as pd
import numpy as np

# %%
# Load the data
df = pd.read_csv('data/wiki_movie_plots_deduped.csv')

# %%
# Displaying 10 first columns
df.head(10) # df.head() without argument will display the first 5 rows

# %%
# Displaying the columns
df.columns

# %%
# Displaying the shape of the data (number of rows, number of columns)
df.shape

# %%
# Displaying the data types of the columns
df.dtypes

# %%
# Displaying the number of unique values in each column
df.nunique()

# %%
# Displaying the number of missing values in each column
df.isnull().sum()

# %%
# How many unknown director
unknown_director = df['Director'].value_counts()['Unknown']
print(f"There are {unknown_director}/{len(df)} unknown directors.")

# %%
# Most prolific directors
df['Director'].value_counts()

# %%
# Distribution by year
df['Release Year'].value_counts().sort_index().plot(kind="bar")

# %%
# Distribution by decade
df['Decade'] = df['Release Year'] // 10 * 10
df['Decade'].value_counts().sort_index().plot(kind="bar")

# %%
# Most prolific comedy director between 2000 and 2010

# Create a condition to filter movies released between the years 2000 and 2010 (inclusive)
condition_year = df['Release Year'].between(2000, 2010)

# Create a condition to filter movies that have 'comedy' in their genre, case insensitive
condition_comedy = df['Genre'].str.contains('comedy', case=False)

# Apply both conditions to the DataFrame to get movies that are comedies released between 2000 and 2010
comedy_2000_2010 = df[condition_year & condition_comedy]
comedy_2000_2010

# %%
comedy_2000_2010['Director'].value_counts()

# %%
# CAST
# Remove null values
print(f"The length of the dataset before removing null values: {len(df)}")
df = df.dropna(subset=['Cast'])
print(f"The length of the dataset after removing null values: {len(df)}")
df['Cast']

# %%
# Remove rows where the 'Cast' column contains 'Unknown'
print(f"The length of the dataset before removing 'Unknown' values: {len(df)}")

# Create a condition to identify rows where the 'Cast' column contains the string 'Unknown', case insensitive
condition = df['Cast'].str.contains('Unknown', case=False)

# Filter the DataFrame to exclude rows where the 'Cast' column contains 'Unknown'
df = df[~condition]
print(f"The length of the dataset after removing 'Unknown' values: {len(df)}")

# Display the 'Cast' column of the filtered DataFrame
df['Cast']

# %%
# Creating a special function that counts the number of actors in the 'Cast' column
def count_actor(cast):
    return len(cast.split(','))
# Applying the function to the 'Cast' column to create a new column 'nb_actor'
df['nb_actor'] = df['Cast'].apply(count_actor)
df['nb_actor']

# %%
# Checking title duplicates
print(f"Number of duplicate titles: {df['Title'].duplicated().sum()}")
# Removing duplicates: 3 methods :
# keep='first': keep the first occurence
# keep='last': keep the last occurence
# keep=False : remove all duplicates

# We remove the duplicates, that is we remove hte rows where the 'Title' column is duplicated, we keep only the first occurence of each title
df = df.drop_duplicates(subset='Title', keep="first")

# %%
# Making a dataframe for the year 1976
df_year_2015 = df[df['Release Year'] == 2015]
print(len(df_year_2015))
df_year_2015
# Out:
# 652
#        Release Year                                 Title Origin/Ethnicity  \
# 16910          2015  The Woman in Black 2: Angel of Death         American
# 16911          2015                               Taken 3         American
# 16912          2015                                 Match         American
# 16913          2015                              Blackhat         American
# 16914          2015                      Little Accidents         American
# ...             ...                                   ...              ...
# 34739          2015          The Advocate: A Missing Body     South_Korean
# 34740          2015                  Collective Invention     South_Korean
# 34741          2015                           The Priests     South_Korean
# 34742          2015                            Inside Men     South_Korean
# 34743          2015                          The Magician     South_Korean
#
#               Director                                               Cast  \
# 16910       Tom Harper  Phoebe Fox\r\nJeremy Irvine\r\nHelen McCrory\r...
# 16911  Olivier Megaton  Liam Neeson\r\nForest Whitaker\r\nFamke Jansse...
# 16912   Stephen Belber  Patrick Stewart\r\nCarla Gugino\r\nMatthew Lil...
# 16913     Michael Mann  Chris Hemsworth\r\nViola Davis\r\nManny Montan...
# 16914  Sarah Colangelo  Elizabeth Banks\r\nBoyd Holbrook\r\nChloë Sevi...
# ...                ...                                                ...
# 34739      Heo Jong-ho                           Lee Sun-kyun, Kim Go-eun
# 34740    Kwon Oh-kwang         Lee Kwang-soo, Park Bo-young, Lee Chun-hee
# 34741    Jang Jae-hyun                       Kim Yoon-seok, Kang Dong-won
# 34742       Woo Min-ho                        Lee Byung-hun, Jo Seung-woo
# 34743    Kim Dae-seung                  Yoo Seung-ho, Go Ara, Kwak Do-won
#
#          Genre                                          Wiki Page  \
# 16910   horror  https://en.wikipedia.org/wiki/The_Woman_in_Bla...
# 16911   action              https://en.wikipedia.org/wiki/Taken_3
# 16912    drama         https://en.wikipedia.org/wiki/Match_(film)
# 16913   action      https://en.wikipedia.org/wiki/Blackhat_(film)
# 16914    drama     https://en.wikipedia.org/wiki/Little_Accidents
# ...        ...                                                ...
# 34739  unknown  https://en.wikipedia.org/wiki/The_Advocate:_A_...
# 34740  unknown  https://en.wikipedia.org/wiki/Collective_Inven...
# 34741  unknown   https://en.wikipedia.org/wiki/The_Priests_(film)
# 34742  unknown    https://en.wikipedia.org/wiki/Inside_Men_(film)
# 34743  unknown      https://en.wikipedia.org/wiki/Joseon_Magician
#
#                                                     Plot  Decade  nb_actor
# 16910  Forty years after the events of the first film...    2010         1
# 16911  Former covert operative Bryan Mills (Liam Nees...    2010         1
# 16912  The film revolves around Tobi, a middle-aged e...    2010         1
# 16913  At a nuclear plant in Chai Wan, Hong Kong, a h...    2010         1
# 16914  In a small American town still living in the s...    2010         1
# ...                                                  ...     ...       ...
# 34739  Byeon Ho-sung is a hotshot lawyer at a big law...    2010         2
# 34740  A medical experiment gone wrong and a man muta...    2010         3
# 34741  A young girl who belongs to Father Kim's paris...    2010         2
# 34742  Lee Kang-hee, an editor at an influential cons...    2010         2
# 34743  A story of the famous magician in Joseon Era w...    2010         3
#
# [652 rows x 10 columns]

# %%
# Selecting the 6th row with column ['wiki page']
url_paddington = df_2000_2010.iloc[5]['Wiki Page']
url_paddington
# Out:
# 'https://en.wikipedia.org/wiki/Paddington_(film)'

# %%
import requests
r = requests.get(url_paddington)
r.status_code
# Out:
# 200

# %%
# Using BeautifulSoup to parse the HTML content
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.content)

# We want the budget and the box office
# We can see that the budget and box office are in the same table
# We can use the 'table' tag to get the table

th_budget = soup.find("table").find('th', class_='infobox-label', string="Budget")
budget_value = th_budget.find_next('td', class_='infobox-data')
print(budget_value.text)

th_box_office = soup.find("table").find('th', class_='infobox-label', string="Box office")
box_office_value = th_box_office.find_next('td', class_='infobox-data')
print(box_office_value.text)
# Out:
# $65 million[5]
# $282.8 million[6]

# %%
# Now we generalize the process to get the budget and box office for all movies 


def get_budget_box_office(url):
    r = requests.get(url)
    if r.status_code != 200:
        return np.nan, np.nan
    soup = BeautifulSoup(r.content)
    try:
        th_budget = soup.find("table").find('th', class_='infobox-label', string="Budget")
    except AttributeError:
        return np.nan, np.nan
    if th_budget is None:
        budget = np.nan
    else:
        budget_value = th_budget.find_next('td', class_='infobox-data')
        budget = budget_value.text
    
    try:
        th_box_office = soup.find("table").find('th', class_='infobox-label', string="Box office")
    except AttributeError:
        return np.nan, np.nan
    if th_box_office is None:
        box_office = np.nan
    else:
        box_office_value = th_box_office.find_next('td', class_='infobox-data')
        box_office = box_office_value.text
    return budget, box_office

# %%
# We do it 50 random movies from 2015
df_2015 = df[
    (df['Release Year'] == 2015) & 
    (df['Origin/Ethnicity'] == 'American')
]
df_2015_random = df_2015.sample(50)
# Apply the get_budget_box_office function and expand the result into separate columns
df_2015_random['Budget'], df_2015_random['Box Office'] = zip(*df_2015_random['Wiki Page'].apply(get_budget_box_office))

# %%
df_2015_random
# Out:
#        Release Year                                  Title Origin/Ethnicity  \
# 16911          2015                                Taken 3         American
# 17014          2015                            The Martian         American
# 16990          2015                           Tomorrowland         American
# 16980          2015                              Blackbird         American
# 16945          2015                      Maps to the Stars         American
# 17002          2015                                    Max         American
# 16927          2015                               The Loft         American
# 16943          2015                                  Focus         American
# 16988          2015                        Pitch Perfect 2         American
# 16925          2015                 We'll Never Have Paris         American
# 16934          2015                             The Voices         American
# 16921          2015                                   Cake         American
# 16932          2015                            Seventh Son         American
# 17025          2015                           The Revenant         American
# 17022          2015                           Daddy's Home         American
# 16977          2015                             True Story         American
# 16916          2015                            Spare Parts         American
# 16946          2015                        Out of the Dark         American
# 17010          2015                              No Escape         American
# 17023          2015                                    Joy         American
# 16941          2015                         McFarland, USA         American
# 16997          2015                           Love & Mercy         American
# 16964          2015                                 Serena         American
# 16972          2015                       Beyond the Reach         American
# 16956          2015                          Run All Night         American
# 16976          2015                        The Road Within         American
# 16920          2015                      The Boy Next Door         American
# 16935          2015                Da Sweet Blood of Jesus         American
# 16991          2015                  When Marnie Was There         American
# 16955          2015                                   Muck         American
# 16923          2015                               Song One         American
# 16987          2015                     Mad Max: Fury Road         American
# 16974          2015                         Monkey Kingdom         American
# 16914          2015                       Little Accidents         American
# 16919          2015                Veronika Decides to Die         American
# 17005          2015                                Minions         American
# 16985          2015                            Hot Pursuit         American
# 16995          2015                              Entourage         American
# 16949          2015  The Second Best Exotic Marigold Hotel         American
# 16963          2015                                   Home         American
# 16989          2015                            Poltergeist         American
# 16947          2015                                Chappie         American
# 16937          2015           Kingsman: The Secret Service         American
# 17020          2015                In the Heart of the Sea         American
# 16962          2015                               Get Hard         American
# 16970          2015                             Lost River         American
# 16936          2015                   Fifty Shades of Grey         American
# 16937  During a mission in the Middle East in 1997, p...    2010         1
# 17020  In 1850, author Herman Melville visits innkeep...    2010         1
# 16962  James King is an extremely wealthy hedge fund ...    2010         1
# 16970  Single mother Billy (Christina Hendricks) live...    2010         1
# 16936  Twenty-one-year-old Anastasia "Ana" Steele is ...    2010         1
# 16993  Raymond "Ray" Gaines is a Los Angeles Fire Dep...    2010         1
# 16975  Paul Blart (Kevin James) narrates his several ...    2010         1
# 16931  Earth and countless other planets were establi...    2010         1
#
#                         Budget                 Box Office
# 16911           $48 million[2]          $326.4 million[2]
# 17014          $108 million[3]          $630.6 million[4]
# 16990      $180–190 million[4]            $209 million[5]
# 16980                      NaN                        NaN
# 16945           $13 million[6]         $4.5 million[7][8]
# 17002           $20 million[2]             $44 million[3]
# 16927           $13 million[1]             $11 million[2]
# 16943   $50.1–65 million[3][4]          $158.8 million[5]
# 16988     $29–31 million[2][3]          $287.5 million[4]
# 16925                      NaN                        NaN
# 16934           $11 million[3]            $2.2 million[4]
# 16921         $7–10 million[4]            $2.9 million[5]
# 16932    $95–110 million[4][5]          $114.2 million[6]
# 17025          $135 million[3]            $533 million[4]
# 17022           $50 million[2]          $242.8 million[3]
# 16977                      NaN            $5.3 million[2]
# 16916                      NaN                        NaN
# 16946            US$10 million                        NaN
# 17010            $5 million[4]           $54.4 million[5]
# 17023           $60 million[2]          $101.1 million[3]
# 16941           $17 million[2]           $45.7 million[3]
# 16997           $10 million[2]           $28.6 million[3]
# 16964        $25–30 million[2]              $5 million[3]
# 16972                      NaN            $1.1 million[1]
# 16956   $50–61.6 million[2][3]           $71.6 million[3]
# 16976                      NaN                        NaN
# 16920         $4 million[3][4]           $52.4 million[4]
# 16935          $1.4 million[2]                        NaN
# 16991                      NaN                        NaN
# 16955                 $250,000                        NaN
# 16923            $6 million[1]                $408,918[2]
# 16987  $154.6–185.2 million[8]          $380.4 million[9]
# 16974         $5–10 million[3]           $17.1 million[4]
# 16914                      NaN                        NaN
# 16919                      NaN  $1.7 million (foreign)[3]
# 17005           $74 million[3]          $1.159 billion[4]
# 16985           $35 million[3]           $51.4 million[3]
# 16995  $27–39 million[2][3][4]           $49.3 million[5]
# 16949           $10 million[4]             $86 million[5]
# 16963          $135 million[3]            $386 million[3]
# 16989           $35 million[1]           $95.4 million[2]
# 16947           $49 million[4]          $102.1 million[4]
# 16937  $81–94 million[4][5][6]          $414.4 million[4]
# 17020          $100 million[3]           $94.3 million[3]
# 16962     $40-44 million[3][4]          $111.8 million[4]
# 16970                      NaN                $615,500[2]
# 16936           $40 million[3]          $569.7 million[3]
# 16993       $110 million[2][3]            $475 million[4]
# 16975     $30–40 million[7][8]          $107.6 million[5]
# 16931   $176–210 million[3][4]            $184 million[3]

# %%
# Exercice
# Transform the columns 'Budget' and 'Box Office' into numerical values
# Using regex 
# Remove the $ sign

# Questions : 
# 1. What is the average budget of the movies in 2015?
# 2. What is the average box office of the movies in 2015?
# 3. Most cheap movies ?
# 4. Most expensive movies ?
